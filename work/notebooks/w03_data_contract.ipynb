# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Huzaif005/FlyrankAI-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of Analysis + Time Window
#
# One row in this dataset represents **one Titanic passenger**. Each row contains demographic and travel-related information along with the observed survival outcome. Since this is a historical dataset from the Titanic disaster in **1912**, it does not contain multiple dates or a time series. Therefore, the analysis covers the complete historical dataset rather than a specific time window.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nColumn Names:")
print(df.columns.tolist())

print("\nFirst Five Records:")
print(df.head())
# Out:
# Rows: 887
# Columns: 8
#
# Column Names:
# ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare']
#
# First Five Records:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# ...

# %% [markdown]
# ## 2. Fields
#
# ### Features
# - Pclass
# - Sex
# - Age
# - SibSp
# - Parch
# - Fare
# - Embarked
#
# ### Label
# - Survived
#
# ### Context
# - Name
# - PassengerId (if available)
#
# ### Excluded
# - Name: Unique identifier, not useful for prediction.
# - Ticket: Mostly unique values with limited predictive value.
# - Cabin: Contains many missing values, making it unreliable for this analysis.

# %%
print("Columns in Dataset:")
for col in df.columns:
    print("-", col)
# Out:
# Columns in Dataset:
# - Survived
# - Pclass
# - Name
# - Sex
# - Age
# - Siblings/Spouses Aboard
# - Parents/Children Aboard
# - Fare

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
#
# The following queries verify the dataset structure, record count, missing values, and feature availability.

# %%
# Dataset shape
print("Dataset Shape:", df.shape)

# Missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Data types
print("\nData Types:")
print(df.dtypes)

# Survival distribution
print("\nSurvival Distribution:")
print(df["Survived"].value_counts())

# Basic statistics
print("\nStatistics:")
print(df.describe())
# Out:
# Dataset Shape: (887, 8)
#
# Missing Values:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64
#
# Data Types:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object
#
# Survival Distribution:
# Survived
# 0    545
# 1    342
# Name: count, dtype: int64
#
# Statistics:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# ...

# %% [markdown]
# ## 4. Data limits
#
# This dataset represents a single historical event and cannot be generalized to all real-world situations. It does not include environmental conditions, passenger behavior, rescue timing, or other factors that may have influenced survival. Some variables, such as Cabin, contain many missing values, which limits their usefulness. Therefore, the findings should be interpreted as observed historical patterns for decision-support and not as causal proof or guaranteed predictions.

# %%
import pandas as pd

df = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
